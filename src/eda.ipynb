# %% [markdown]
# # init

# %%
import numpy as np
import pandas as pd
import polars as pl
from timeit import timeit
import os, sys
print(os.getcwd())
os.chdir('/gpfs/data/healthcare-allocate/CLIF-MIMIC/code')
print(os.getcwd())

proj_root = "/gpfs/data/healthcare-allocate/CLIF-MIMIC"
if proj_root not in sys.path:
    sys.path.append(proj_root)

from code.custom_utils import *
# Out:
# /gpfs/data/healthcare-allocate/CLIF-MIMIC
# /gpfs/data/healthcare-allocate/CLIF-MIMIC/code

# %%
def load_mimic_table(module, table, file_type):
    if file_type in ["pq", "parquet"]:
        return pd.read_parquet(f'../mimic-iv-2.2/{module}/{table}.parquet')
    elif file_type == "csv":
        return pd.read_csv(f'../mimic-iv-2.2/{module}/{table}.csv.gz')

d_items = load_mimic_table("icu", "d_items", "csv")
chartevents = load_mimic_table("icu", "chartevents", "parquet")
procedureevents = load_mimic_table("icu", "procedureevents", "csv")
datetimeevents = load_mimic_table("icu", "datetimeevents", "csv")
inputevents = load_mimic_table("icu", "inputevents", "csv")
outputevents = load_mimic_table("icu", "outputevents", "csv")
# d_items = pd.read_csv("../mimic-iv-2.2/icu/d_items.csv.gz")
# chartevents = pd.read_parquet('../mimic-iv-2.2/icu/chartevents.parquet')

# %%
vitals_mapping = pd.read_csv("../mapping/mimic-to-clif-mappings - vitals.csv")
vitals_mapping.head()
# Out:
#   vital_category  itemid                    label = vital_name  \
# 0            sbp  220179  Non Invasive Blood Pressure systolic
# 1            sbp  220050      Arterial Blood Pressure systolic
# 2            sbp  220059    Pulmonary Artery Pressure systolic
# 3            sbp  225309                       ART BP Systolic
# 4            sbp  228152     Aortic Pressure Signal - Systolic
#
#                         abbreviation linksto             category unitname  \
# 0                               NBPs     NaN  Routine Vital Signs     mmHg
# 1                               ABPs     NaN  Routine Vital Signs     mmHg
# 2                               PAPs     NaN         Hemodynamics     mmHg
# 3                    ART BP Systolic     NaN  Routine Vital Signs     mmHg
# 4  Aortic Pressure Signal - Systolic     NaN              Impella    mmHg.
#
#   param_type    count value_instances  meas_site_name note / comment  \
# ...

# %% [markdown]
# # utils

# %% [markdown]
# ## `ItemFinder` class

# %%
def item_id_to_feature_value(item_id: int, col: str = "label", df = d_items):
    '''
    Find the corresponding feature value of an item by id.
    i.e. find the label, or linksto, or item with id 226732.
    '''
    return df.loc[df["itemid"] == item_id, col].values[0]

def item_id_to_label(item_id: int) -> str:
    '''
    Helper function that returns the "label" string of an item given its item_id. 
    '''
    return item_id_to_feature_value(item_id)

def item_id_to_events_df(item_id: int) -> pd.DataFrame:
    '''
    Return in a pandas df all the events associated with an item id.
    '''
    # find whether it is chartevents, or procedure events, etc.
    linksto_table_name = item_id_to_feature_value(item_id, col = "linksto")
    # turn string into a dj object
    linksto_df: pd.DataFrame = globals()[linksto_table_name]
    return linksto_df.loc[linksto_df["itemid"] == item_id, :]

class ItemFinder():
    def __init__(self, kw, df = d_items, col: str = "label", 
                 case: bool = False):
        '''
        Look up an item by keyword from the `d_items` table of the `icu` module.
        - df = `d_items`
        - col = {"label", "abbr"}
        '''
        self.kw = kw 
        self.df = df
        self.col = "abbreviation" if col == "abbr" else col
        self.case = case

        # df of items that match the key words
        self.kw_items_df = df[
            df[self.col].str.contains(kw, case = case, na = False)
        ]
        # list of ids for items that match the key words
        self.kw_items_ids = self.kw_items_df["itemid"].values
        # a string list of non-duplicated events table names, e.g. ["chartevents", "procedureevents"]
        self.linksto_table_names = self.kw_items_df["linksto"].unique()
                                                                
        self.kw_chartevents = chartevents.loc[
            chartevents["itemid"].isin(self.kw_items_ids),
            :
        ]
        self.item_freq = self.generate_item_freq()

        self.candidate_table = self.make_candidate_table()

    def generate_item_freq(self):
        '''
        Iterative over each events table, find the items freq therein, and combine into one df.
        '''
        freq_df_ls = [] # a list of df's
        for table_name in self.linksto_table_names:
            # fetch the object by name, i.e. chartevents, procedureevents, etc.
            events_df = globals()[table_name]
            # a df of events associated with the key word items
            kw_events_df = events_df.loc[
                events_df["itemid"].isin(self.kw_items_ids),
                :
            ]
            # a df of item freq for one event type  
            item_freq_df = kw_events_df.value_counts("itemid")

            # check if the df is empty
            if not item_freq_df.empty:
                freq_df_ls.append(item_freq_df)
        
        # check if the list len is 0, meaning 
        if len(freq_df_ls) != 0:
            # return a df of all the item freq of all events table concat-ed together
            return pd.concat(freq_df_ls)
        else: 
            return self.kw_chartevents.value_counts("itemid")

    def make_candidate_table(self):
        '''
        # TODO
        '''
        if not self.item_freq.empty:
            return (
                self.kw_items_df
                .loc[:, ["itemid", "label", "abbreviation", "linksto", "category", "unitname", "param_type"]]
                # FIXME
                .join(self.item_freq, on = "itemid", validate = "1:1")
                .sort_values(by = "count", ascending = False) 
                .assign(
                    value_instances = lambda x: x["itemid"].apply(ItemFinder.item_id_to_value_instances)
                )
            )
        else: 
            return "No matching result found."
        
    @staticmethod
    def item_id_to_value_instances(item_id: int):
        '''
        Wrapper
        '''
        label = item_id_to_feature_value(item_id, "label")

        param_type = item_id_to_feature_value(item_id, "param_type")
        
        if param_type == "Numeric":
            val_instances = ItemFinder.item_id_to_value_instances_numeric(item_id)
        elif param_type == "Text":
            val_instances = ItemFinder.item_id_to_value_instances_categorical(item_id).to_dict()
        else:
            return param_type
        print(f"item label: {label}; value instances: {str(val_instances)}")
        return str(val_instances)

    @staticmethod
    def item_id_to_value_instances_categorical(item_id: int):
        '''
        Return all the unique categories
        '''
        assoc_chartevents = chartevents.loc[chartevents["itemid"] == item_id, :]
        categories = assoc_chartevents.value_counts("value") # a pd series
        return categories
    
    @staticmethod
    def item_id_to_value_instances_numeric(item_id: int):
        '''
        Find max, min, mean of a continuous, or numeric, item.
        '''
        valuenum_col = chartevents.loc[chartevents["itemid"] == item_id, :]["valuenum"]
        val_max, val_min, val_mean = valuenum_col.max(), valuenum_col.min(), valuenum_col.mean()
        return f"Max: {val_max}, Min: {val_min}, Mean: {val_mean}"

# %% [markdown]
# # `hosp` module

# %%
d_labitems = pd.read_csv("mimic-iv-2.2/hosp/d_labitems.csv.gz")

# %%
# d_labitems.head(10)
contains = d_labitems["label"].str.contains("temp", case=False, na=False)
d_labitems[contains]
# Out:
#     itemid        label  fluid   category
# 23   50825  Temperature  Blood  Blood Gas

# %%
d_labitems["fluid"].unique()
d_labitems["category"].unique()
# Out:
# array(['Blood Gas', 'Chemistry', 'Hematology'], dtype=object)

# %%
omr = pd.read_csv("../mimic-iv-2.2/hosp/omr.csv.gz")
omr.head(10)
# Out:
#    subject_id   chartdate  seq_num      result_name result_value
# 0    10000032  2180-04-27        1   Blood Pressure       110/65
# 1    10000032  2180-04-27        1     Weight (Lbs)           94
# 2    10000032  2180-05-07        1      BMI (kg/m2)         18.0
# 3    10000032  2180-05-07        1  Height (Inches)           60
# 4    10000032  2180-05-07        1     Weight (Lbs)        92.15
# 5    10000032  2180-05-07        2     Weight (Lbs)        92.15
# 6    10000032  2180-05-07        3     Weight (Lbs)        92.15
# 7    10000032  2180-05-07        4     Weight (Lbs)        92.15
# 8    10000032  2180-05-07        5     Weight (Lbs)        92.15
# 9    10000032  2180-05-07        6     Weight (Lbs)        92.15

# %% [markdown]
# # `icu` module

# %% [markdown]
# ### `d_items`

# %% [markdown]
# ### `chartevents`

# %%
# resave into parquet
chartevents = load_gz_csv("mimic-iv-2.2/icu/chartevents.csv.gz")
chartevents.to_parquet('mimic-iv-2.2/icu/chartevents.parquet')

# %%
chartevents.loc[
    chartevents["itemid"] == 224689, :]["valuenum"].agg(["max","min"])
# Out:
# max    2843.0
# min       0.0
# Name: valuenum, dtype: float64

# %%
items_category_freq = d_items.value_counts("category")

# %% [markdown]
# ### `procedureevents`

# %%
item_id_to_events_df()
# Out:
#    subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0    10000032  29079034  39553978       88981.0  2180-07-23 14:43:00
# 1    10000032  29079034  39553978           NaN  2180-07-23 14:24:00
# 2    10000032  29079034  39553978           NaN  2180-07-23 14:24:00
# 3    10000980  26913865  39765666           NaN  2189-06-27 09:01:00
# 4    10000980  26913865  39765666           NaN  2189-06-27 09:15:00
# 5    10000980  26913865  39765666           NaN  2189-06-27 09:16:00
# 6    10001217  24597018  37067082        7355.0  2157-11-21 20:30:00
# 7    10001217  24597018  37067082        7355.0  2157-11-21 20:30:00
# 8    10001217  24597018  37067082       72136.0  2157-11-21 14:00:00
# 9    10001217  27703517  34592300       18215.0  2157-12-19 20:19:00
#
#                endtime                storetime  itemid       value valueuom  \
# 0  2180-07-23 14:44:00      2180-07-23 14:43:00  225966    1.000000      NaN
# ...

# %% [markdown]
# # `vitals` table

# %% [markdown]
# ### MAPPING

# %%
def map_one_vitals_item(item_id: int) -> pd.DataFrame:
    '''
    create the rows in a vitals table corresponding to one item from MIMIC, based on item id.

    it is a simple procedure that does not even need reshaping.
    '''
    # label => *_name 
    vital_name = item_id_to_feature_value(item_id, "label")
    vital_category = item_id_to_feature_value(item_id, "vital_category", df = vitals_mapping)
    meas_site_name = item_id_to_feature_value(item_id, "meas_site_name", df = vitals_mapping)

    df = (
        item_id_to_events_df(item_id)
        # find all the relevant columns of the events table to be transformed
        .loc[:,["hadm_id", "charttime", "itemid", "value"]]
        .rename(columns = {
            "hadm_id": "encounter_id", 
            "charttime": "recorded_dttm",
            "value": "vital_value"
            })
        .assign(
            vital_name = vital_name,
            vital_category = vital_category,
            meas_site_name = meas_site_name
        )
        # reorder the columns
        .reindex(
            columns = ["encounter_id", "recorded_dttm", "vital_name", "vital_category", "vital_value", "meas_site_name"]
        )    
    )
    return df

class MimicMapper():
    def __init__(self) -> None:
        pass

# %%
# item_id = 220050
permissible_meas_site_names = ['not specified', 'arterial', 'core']

vital_items_ids = vitals_mapping.loc[
    vitals_mapping["meas_site_name"].isin(permissible_meas_site_names), :
]["itemid"].unique()

# deal with the regular cases: all vitals other than temp_c
vitals_dfs_list = []
for item_id in vital_items_ids:
    # clif df for one mimic item
    vitals_df = map_one_vitals_item(item_id)
    vitals_dfs_list.append(vitals_df)

vitals_dfs = pd.concat(vitals_dfs_list)
# TODO: remove the mimic item temp c or temp f from this df

# %%
vitals_dfs
# Out:
#            encounter_id        recorded_dttm  \
# 0              29079034  2180-07-23 21:01:00
# 4              29079034  2180-07-23 22:00:00
# 10             29079034  2180-07-23 19:00:00
# 21             29079034  2180-07-23 20:00:00
# 163            29079034  2180-07-23 14:11:00
# ...                 ...                  ...
# 313446049      21784060  2126-10-22 04:00:00
# 313446200      21784060  2126-10-22 06:00:00
# 313452288      21784060  2126-10-21 21:00:00
# 313452316      21784060  2126-10-21 23:00:00
# 313452322      21784060  2126-10-22 05:00:00
#
#                                      vital_name vital_category vital_value  \
# 0          Non Invasive Blood Pressure systolic            sbp          82
# 4          Non Invasive Blood Pressure systolic            sbp          85
# 10         Non Invasive Blood Pressure systolic            sbp          93
# 21         Non Invasive Blood Pressure systolic            sbp          90
# ...

# %%
# TODO: deal with the special case: temp_c
# find all the temp related events:
temp_f_events = item_id_to_events_df(223761)
temp_c_events = item_id_to_events_df(223762)
temp_site_events = item_id_to_events_df(224642)
temp_events_df = pd.concat([temp_f_events, temp_c_events, temp_site_events])
temp_events_df
# Out:
#            subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 17           10000032  29079034  39553978       66056.0  2180-07-23 20:00:00
# 162          10000032  29079034  39553978       88981.0  2180-07-23 14:00:00
# 371          10000032  29079034  39553978       88981.0  2180-07-23 17:00:00
# 550          10000980  26913865  39765666       36518.0  2189-06-27 09:07:00
# 730          10000980  26913865  39765666       36518.0  2189-06-27 12:00:00
# ...               ...       ...       ...           ...                  ...
# 313644553    19999987  23865745  36195440       86756.0  2145-11-03 04:00:00
# 313644735    19999987  23865745  36195440       90295.0  2145-11-02 23:24:00
# 313644811    19999987  23865745  36195440       90295.0  2145-11-02 23:41:00
# 313644876    19999987  23865745  36195440       91879.0  2145-11-04 20:00:00
# 313644991    19999987  23865745  36195440       91879.0  2145-11-04 21:00:00
#
# ...

# %%
stay_ids[:10]
# Out:
# array([39553978, 39765666, 37067082, 34592300, 31205490, 37510196,
#        39060235, 32358465, 33685454, 31090461])

# %%
vitals_temp_site_mapping = {
    'Oral': 'not specified', 'Blood': 'not specified', 'Axillary': 'not specified', 
    'Rectal': 'core', 'Esophogeal': 'core', 'Temporal': 'not specified', 'Tympanic': 'core'}

vitals_temp_uom_to_name_mapping = {
    '°F': 'Temperature Fahrenheit', '°C': 'Temperature Celsius'
}

# %%
def map_temp_for_one_stay_id(stay_id):
    df = temp_events_df.loc[
        temp_events_df["stay_id"] == stay_id, :
    ]

    avail_item_ids = df["itemid"].unique()

    if len(avail_item_ids)!= 3:
        return pd.DataFrame()

    wider_df = df.pivot(
        index = ["hadm_id", "charttime"], 
        columns = ["itemid"],
        values = ["value","valueuom"]
    ).reset_index()

    # return wider_df

    wider_df_temp_c = wider_df[
        [("hadm_id",""), ("charttime",""), ('value',223762), ("value", 224642), ("valueuom", 223762)]
        ].dropna()

    wider_df_temp_c

    wider_df_temp_c = wider_df[
        [("hadm_id",""), ("charttime",""), ('value',223762), ("value", 224642), ("valueuom", 223762)]
        ].dropna()

    wider_df_temp_f = wider_df[
        [("hadm_id",""), ("charttime",""), ('value',223761), ("value", 224642), ("valueuom", 223761)]
        ].dropna()

    temp_col_names = ["encounter_id", "recorded_dttm", "vital_value", "temp_site", "uom"]
    wider_df_temp_c.columns = temp_col_names
    wider_df_temp_f.columns = temp_col_names

    df_clean = pd.concat([wider_df_temp_c, wider_df_temp_f])
    df_clean["vital_category"] = "temp_c"
    df_clean["vital_value"] = df_clean["vital_value"].apply(float)
    df_clean.loc[df_clean['uom'] == '°F', 'vital_value'] = (
        (df_clean.loc[df_clean['uom'] == '°F', 'vital_value'] - 32) * 5 / 9
    )
    df_clean["meas_site_name"] = df_clean["temp_site"].apply(
        lambda x: vitals_temp_site_mapping[x])
    df_clean["vital_name"] = df_clean["uom"].apply(
        lambda x: vitals_temp_uom_to_name_mapping[x])

    df_clean = df_clean.reindex(
        columns = [
            "encounter_id", "recorded_dttm", "vital_name", "vital_category", "vital_value", "meas_site_name"
        ]
        )
    
    return df_clean

# %%
map_temp_for_one_stay_id(39765666)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### LOOP

# %%
stay_ids = temp_events_df["stay_id"].unique()
# init
temp_c_df_list = []

for stay_id in stay_ids:
    df = map_temp_for_one_stay_id(stay_id)
    temp_c_df_list.append(df)

temp_c_df = pd.concat(temp_c_df_list)

# %%
# COMBINE:
# remove temp_c from the previous version
vitals_df_clean = vitals_dfs.query('vital_category != "temp_c"')

vitals_df_final = pd.concat([
    vitals_df_clean, temp_c_df
])

# %%
vitals_df_final["vital_value"] = vitals_df_final["vital_value"].apply(str)

# %%
# save
vitals_df_final.to_parquet('../rclif/rclif_vitals.parquet')

# %%
# EDA CODE:
# first, reshape one stay_id
temp_events_of_each_stay_df = temp_events_df.loc[
    temp_events_df["stay_id"] == 37510196, :
]

wider_df = temp_events_of_each_stay_df.pivot(
    index = ["hadm_id", "charttime"], 
    columns = ["itemid"],
    values = ["value","valueuom"]
).reset_index()

wider_df_temp_c = wider_df[
    [("hadm_id",""), ("charttime",""), ('value',223762), ("value", 224642), ("valueuom", 223762)]
    ].dropna()

wider_df_temp_c

wider_df_temp_c = wider_df[
    [("hadm_id",""), ("charttime",""), ('value',223762), ("value", 224642), ("valueuom", 223762)]
    ].dropna()

wider_df_temp_f = wider_df[
    [("hadm_id",""), ("charttime",""), ('value',223761), ("value", 224642), ("valueuom", 223761)]
    ].dropna()

temp_col_names = ["encounter_id", "recorded_dttm", "vital_value", "temp_site", "uom"]
wider_df_temp_c.columns = temp_col_names
wider_df_temp_f.columns = temp_col_names

df_clean = pd.concat([wider_df_temp_c, wider_df_temp_f])
df_clean["vital_category"] = "temp_c"
df_clean["vital_value"] = df_clean["vital_value"].apply(float)
df_clean.loc[df_clean['uom'] == '°F', 'vital_value'] = (
    (df_clean.loc[df_clean['uom'] == '°F', 'vital_value'] - 32) * 5 / 9
)
df_clean["meas_site_name"] = df_clean["temp_site"].apply(
    lambda x: vitals_temp_site_mapping[x])
df_clean["vital_name"] = df_clean["uom"].apply(
    lambda x: vitals_temp_uom_to_name_mapping[x])

df_clean = df_clean.reindex(
        columns = [
            "encounter_id", "recorded_dttm", "vital_name", "vital_category", "vital_value", "meas_site_name"
        ]
    )
# TODO: remove blood columns at one point?

# %%
df_clean
# Out:
#     encounter_id        recorded_dttm              vital_name vital_category  \
# 0       26184834  2131-01-11 06:47:00     Temperature Celsius         temp_c
# 1       26184834  2131-01-11 08:00:00     Temperature Celsius         temp_c
# 2       26184834  2131-01-11 09:00:00     Temperature Celsius         temp_c
# 3       26184834  2131-01-11 10:00:00     Temperature Celsius         temp_c
# 4       26184834  2131-01-11 11:00:00     Temperature Celsius         temp_c
# ..           ...                  ...                     ...            ...
# 74      26184834  2131-01-19 08:00:00  Temperature Fahrenheit         temp_c
# 75      26184834  2131-01-19 12:00:00  Temperature Fahrenheit         temp_c
# 76      26184834  2131-01-19 16:00:00  Temperature Fahrenheit         temp_c
# 77      26184834  2131-01-19 20:00:00  Temperature Fahrenheit         temp_c
# 78      26184834  2131-01-20 00:00:00  Temperature Fahrenheit         temp_c
#
#     vital_value meas_site_name
# ...

# %%
temp_events_df.loc[
    temp_events_df["stay_id"] == 39765666, :
]
# seems like: if temp_site == Blood, then no corresponding temp val recorded
# Out:
#      subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 550    10000980  26913865  39765666       36518.0  2189-06-27 09:07:00
# 730    10000980  26913865  39765666       36518.0  2189-06-27 12:00:00
# 854    10000980  26913865  39765666       36518.0  2189-06-27 16:00:00
# 551    10000980  26913865  39765666       36518.0  2189-06-27 09:07:00
# 733    10000980  26913865  39765666       36518.0  2189-06-27 12:00:00
# 857    10000980  26913865  39765666       36518.0  2189-06-27 16:00:00
#
#                storetime  itemid     value  valuenum valueuom  warning
# 550  2189-06-27 09:07:00  223761        98      98.0       °F      0.0
# 730  2189-06-27 12:53:00  223761      97.7      97.7       °F      0.0
# 854  2189-06-27 16:12:00  223761      98.7      98.7       °F      0.0
# 551  2189-06-27 09:07:00  224642  Axillary       NaN     None      0.0
# 733  2189-06-27 12:53:00  224642      Oral       NaN     None      0.0
# ...

# %% [markdown]
# ### Routine Vital Signs

# %%
routine_vitals = ItemFinder("Routine Vital Signs", col = "category").candidate_table
routine_vitals
# Out:
# item label is Heart Rate
# item label is Heart Rhythm
# categories are ['SR (Sinus Rhythm)', 'ST (Sinus Tachycardia) ', 'AF (Atrial Fibrillation)', 'SB (Sinus Bradycardia)', 'V Paced', '1st AV (First degree AV Block) ', 'A Paced', 'AV Paced', 'A Flut (Atrial Flutter) ', 'RBBB (Right Bundle Branch Block) ', 'SA (Sinus Arrhythmia)', 'LBBB (Left Bundle Branch Block) ', 'JR (Junctional Rhythm)', '3rd AV (Complete Heart Block) ', 'SVT (Supra Ventricular Tachycardia)', '2nd AV W-M1 (Second degree AV Block Wenckebach - Mobitz1) ', 'JT (Junctional Tachycardia) ', 'WAP (Wandering atrial pacemaker)', '2nd AV M2 (Second degree AV Block - Mobitz 2) ', 'MAT (Multifocal atrial tachycardia)', 'VT (Ventricular Tachycardia) ', 'PAT (Paroxysmal Atrial Tachycardia)', 'Asystole', 'Idioventricular', 'VF (Ventricular Fibrillation) ', 'PJT (Paroxysmal Junctional Tachycardia) ']
# item label is Ectopy Type 1
# ...

# %% [markdown]
# ### `respiratory_rate`

# %% [markdown]
# ### `temp_c`

# %% [markdown]
# #### temp site

# %%
# levels of temp_site
# item_id_to_events_df(224642).value_counts("value")
str(ItemFinder.item_id_to_value_instances_categorical(224642).to_dict())
# Out:
# "{'Oral': 1278499, 'Blood': 269153, 'Axillary': 157738, 'Rectal': 50577, 'Esophogeal': 43733, 'Temporal': 39990, 'Tympanic': 2697}"

# %%
temp_f_events = item_id_to_events_df(223761)
temp_c_events = item_id_to_events_df(223762)
temp_site_events = item_id_to_events_df(224642)

shared_stay_ids = set.intersection(
    set(temp_c_events["stay_id"].unique()),
    set(temp_site_events["stay_id"].unique())
)

shared_stay_ids
# Out:
# {31326208,
#  33619974,
#  36503558,
#  36470794,
#  32768012,
#  34766861,
#  36110350,
#  39026709,
#  32276504,
#  31719450,
#  35520541,
#  38797343,
#  38993953,
#  31031331,
#  35520548,
#  35258406,
#  30539822,
#  33882161,
#  37290033,
#  33751102,
#  36864067,
#  32931914,
#  33718357,
#  31588440,
#  32997479,
#  34078845,
#  38404233,
#  31424650,
#  36470924,
#  34570388,
#  32931989,
#  33226902,
#  31293601,
#  39190690,
#  30867628,
#  37322924,
#  38371514,
#  39157951,
#  36405440,
#  39157960,
#  31654092,
#  35881172,
#  38830299,
#  37388511,
#  33358048,
#  31457508,
#  30638314,
#  32178416,
#  36831473,
#  32637171,
#  31686910,
#  39518463,
#  32604416,
#  34636031,
#  39616772,
#  30408968,
#  34177290,
#  34668810,
#  30114063,
#  37650707,
#  34898197,
#  37486870,
#  35488025,
#  30933276,
#  38535456,
#  36176169,
#  38404395,
#  34308401,
#  36208960,
#  33784138,
#  38961482,
#  32932176,
#  34308434,
#  30867816,
#  33816940,
#  39321969,
# ...

# %%
temp_c_events
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 temp_c_events
#
# NameError: name 'temp_c_events' is not defined

# %%
sid = 33851436
f_events_slc = temp_f_events.loc[
    temp_f_events["stay_id"] == sid, :
]
site_events_slc = temp_site_events.loc[
    temp_site_events["stay_id"] == sid, :
]

# %% [markdown]
# ### `map`

# %%
ItemFinder("map", col="abbr").candidate_table
# Out:
# item label is IABP Mean
# item label is MapApacheIIScore
# item label is PotassiumApacheIIScore
# item label is SodiumApacheIIScore
# item label is MapApacheIIValue
# item label is PotassiumApacheIIValue
# item label is SodiumApacheIIValue
# item label is MapScore_ApacheIV
# item label is MAP_ApacheIV
#       itemid                   label            abbreviation  \
# 635   224322               IABP Mean          MAP - Assisted
# 1975  226765        MapApacheIIScore        MapApacheIIScore
# 1981  226771  PotassiumApacheIIScore  PotassiumApacheIIScore
# 1985  226775     SodiumApacheIIScore     SodiumApacheIIScore
# 1976  226766        MapApacheIIValue        MapApacheIIValue
# 1982  226772  PotassiumApacheIIValue  PotassiumApacheIIValue
# 1986  226776     SodiumApacheIIValue     SodiumApacheIIValue
# 2067  227024       MapScore_ApacheIV       MapScore_ApacheIV
# 2066  227023            MAP_ApacheIV            MAP_ApacheIV
#
# ...

# %%
ItemFinder("Mean art").candidate_table
# Out:
# Empty DataFrame
# Columns: [itemid, label, abbreviation, category, unitname, param_type, count, value_instances]
# Index: []

# %% [markdown]
# ### sbp

# %% [markdown]
# ### dbp

# %% [markdown]
# ### `pulse`

# %%
ItemFinder.find_value_instances(229770)
# Out:
# item label is Resting Pulse Rate (COWS)
# Index(['Pulse rate 80 or below', 'Pulse rate 81-100', 'Pulse rate 101-120',
#        'Pulse rate greater than 120'],
#       dtype='object', name='value')

# %% [markdown]
# ### spo2

# %%
ItemFinder('spo2', col = "abbr").create_candidate_table()
# Out:
#       itemid                                     label  \
# 36    220277               O2 saturation pulseoxymetry
# 346   223770   O2 Saturation Pulseoxymetry Alarm - Low
# 345   223769  O2 Saturation Pulseoxymetry Alarm - High
# 1810  226253                          SpO2 Desat Limit
# 3920  229862             Forehead SpO2 Sensor in Place
#
#                        abbreviation             category unitname param_type  \
# 36                             SpO2          Respiratory        %    Numeric
# 346                SpO2 Alarm - Low               Alarms        %    Numeric
# 345               SpO2 Alarm - High               Alarms        %    Numeric
# 1810               SpO2 Desat Limit               Alarms        %    Numeric
# 3920  Forehead SpO2 Sensor in Place  Routine Vital Signs      NaN   Checkbox
#
#         count
# 36    6324341
# 346    622764
# 345    619601
# 1810   600821
# 3920       35

# %% [markdown]
# ### `height_inches`

# %%
ItemFinder("height").create_candidate_table()
# Out:
#       itemid        label abbreviation category unitname param_type  count
# 1941  226707       Height       Height  General     Inch    Numeric  33707
# 1945  226730  Height (cm)  Height (cm)  General       cm    Numeric  33707

# %% [markdown]
# # `labs` table

# %%
ItemFinder("protein").create_candidate_table()
# Out:
#       itemid                       label                abbreviation  \
# 2205  227444    C Reactive Protein (CRP)    C Reactive Protein (CRP)
# 157   220650               Total Protein               Total Protein
# 1794  226184  Estimated Protein Needs/Kg  Estimated Protein Needs/Kg
# 93    220454                     Protein                     Protein
# 148   220612   ZC Reactive Protein (CRP)   ZC Reaction Protein (CRP)
# 1667  225970                 Beneprotein                 Beneprotein
# 3514  229296   Vital High Protein (Full)   Vital High Protein (Full)
# 3713  229583                Beneprotein.                Beneprotein.
#
#                      category unitname        param_type   count
# 2205                     Labs      NaN  Numeric with tag  2749.0
# 157                      Labs      NaN           Numeric  2478.0
# 1794                  General     g/kg           Numeric   450.0
# 93                Ingredients    grams        Ingredient     NaN
# ...

# %% [markdown]
# # `respiratory_support` table

# %%
resp_items_df = ItemFinder("Respiratory", col="category").candidate_table
resp_items_df
# Out:
# item label: Respiratory Rate; value instances: Max: 2355560.0, Min: 0.0, Mean: 20.459964592066456
# item label: O2 saturation pulseoxymetry; value instances: Max: 9900000.0, Min: -272.0, Mean: 104.82763597187437
# item label: O2 Delivery Device(s); value instances: {'Endotracheal tube': 467931, 'Nasal cannula': 417453, 'Tracheostomy tube': 90713, 'Aerosol-cool': 68754, 'Face tent': 60388, 'Trach mask ': 50917, 'High flow nasal cannula': 23248, 'Bipap mask ': 19004, 'High flow neb': 17651, 'Non-rebreather': 10898, 'CPAP mask ': 8529, 'Venti mask ': 5144, 'Other': 4550, 'Medium conc mask ': 4421, 'Oxymizer': 4117, 'T-piece': 3441, 'Ultrasonic neb': 27, 'Vapomist': 15}
# item label: Inspired O2 Fraction; value instances: Max: 10050.0, Min: 0.0, Mean: 48.94540639505812
# item label: PEEP set; value instances: Max: 8774580.0, Min: -5.0, Mean: 26.214116360816025
# item label: Tidal Volume (observed); value instances: Max: 709461.0, Min: 0.0, Mean: 470.8951592275197
# ...

# %%
ItemFinder("Respiratory", col="category").candidate_table

# %% [markdown]
# ### `peak_inspiratory_pressure_*`

# %%
ItemFinder("ipap").candidate_table
# Out:
# item label: BiPap Mask; value instances: ['Oral/Nasal', 'Total face', 'Nasal', 'Pillows', 'Not applicable']
# item label: BiPap Mode; value instances: ['Spontaneous (S)', 'Spontaneous/Timed (S/T) (Back up)', 'Not applicable', 'Timed (T)']
# item label: BiPap EPAP; value instances: Max: 136.0, Min: 0.0, Mean: 7.367685054219708
# item label: BiPap IPAP; value instances: Max: 45.0, Min: 0.0, Mean: 13.283781379719311
# item label: BiPap O2 Flow; value instances: Max: 100.0, Min: 0.0, Mean: 6.749544257646344
# item label: BiPap bpm (S/T -Back up); value instances: Max: 22.0, Min: 0.0, Mean: 10.139130434782608
#       itemid                     label              abbreviation      linksto  \
# 2284  227578                BiPap Mask                BiPap Mask  chartevents
# 2283  227577                BiPap Mode                BiPap Mode  chartevents
# 2285  227579                BiPap EPAP                BiPap EPAP  chartevents
# ...

# %% [markdown]
# ### `tracheostomy`

# %%
ItemFinder("Airway").candidate_table
# Out:
# item label: Mean Airway Pressure; value instances: Max: 257708.0, Min: -1.0, Mean: 10.914437783590904
# item label: Airway Type; value instances: ['Oral', 'Nasal trumpet', 'Nasotracheal']
# item label: Airway Location; value instances: ['Oral', 'Not applicable', 'L Nare', 'R Nare']
# item label: Airway Size (mm); value instances: ['Not applicable', '8.0', '7.0', '9.0', '7.5']
# item label: Airway problems; value instances: ['P > 30cm/H2O', 'Positional leak around cuff', 'No leak with cuff down', 'Cuff / valve leak']
# item label: Unable to complete Airway Assessment (Intubation); value instances: []
#       itemid                                              label  \
# 806   224697                               Mean Airway Pressure
# 385   223836                                        Airway Type
# 2280  227567                                    Airway Location
# 2281  227568                                   Airway Size (mm)
# ...

# %%
ItemFinder("trach").candidate_table
# Out:
# item label: Trach Tube Type; value instances: ['Perc Trach ', 'Cuffed', 'Standard', 'Inner Cannula', 'TTS (Tight to Shaft)', 'Adjustable Neck Flange', 'Extra Length', 'Uncuffed', 'Wire Reinforced', 'Not applicable', 'Foam Cuff', 'Fenestrated']
# item label: Trach Tube Manufacturer; value instances: ['Portex', 'Bivona', 'Shiley', 'Not applicable', 'Boston Med']
# item label: Trach Tube Size (I.D.); value instances: ['8.0mm', '7.0mm', '6.0mm', '9.0mm', 'Not applicable', '5.0mm', '10.0mm', '4.0mm']
# item label: ZTrach Care; value instances: []
# item label: Tracheal Confirmation (Intubation); value instances: []
#       itemid                               label  \
# 886   224829                     Trach Tube Type
# 887   224830             Trach Tube Manufacturer
# 888   224831              Trach Tube Size (I.D.)
# 2136  227130                          Trach Care
# 1306  225448           Percutaneous Tracheostomy
# 1808  226237                   Open Tracheostomy
# ...

# %%
item_id_to_events_df(227130)
# Out:
#            subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 142713       10004401  22869003  38292466       16647.0  2144-04-07 15:41:00
# 143071       10004401  22869003  38292466       16647.0  2144-04-08 12:00:00
# 143385       10004401  22869003  38292466       16681.0  2144-04-05 20:22:00
# 145916       10004401  22869003  38292466       96601.0  2144-04-07 21:12:00
# 146563       10004401  22869003  38292466       96601.0  2144-04-08 22:28:00
# ...               ...       ...       ...           ...                  ...
# 313425095    19995258  26871572  38607853       29441.0  2130-06-12 02:00:00
# 313442191    19995595  21784060  34670930       48419.0  2126-10-24 04:17:00
# 313445749    19995595  21784060  34670930       68716.0  2126-10-21 20:00:00
# 313445852    19995595  21784060  34670930       68716.0  2126-10-21 23:00:00
# 313560115    19997843  20277361  32880062       21562.0  2120-11-19 22:00:00
#
# ...

# %%
item_id_to_events_df(225448, procedureevents)
# Out:
#         subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 311       10004401  29988601  32773003       11464.0  2144-01-31 14:30:00
# 3921      10057482  25416257  38980177       13374.0  2145-04-07 16:16:00
# 3949      10057482  25416257  38980177       40517.0  2145-04-07 15:30:00
# 4927      10078115  28052678  36265401       98628.0  2147-12-09 11:40:00
# 7480      10123036  29540743  30112389       95471.0  2168-06-15 16:06:00
# ...            ...       ...       ...           ...                  ...
# 693567    19969918  29544887  35223685       82842.0  2186-02-04 14:30:00
# 693602    19970265  24514478  38356273       12302.0  2115-04-03 10:00:00
# 693755    19970491  25338284  30244200       17526.0  2129-06-01 11:24:00
# 693975    19971771  26230047  38668070       44464.0  2117-05-09 15:24:00
# 695073    19989783  26984195  32761676       29205.0  2130-07-22 11:15:00
#
#                     endtime            storetime  itemid  value valueuom  ...  \
# ...

# %% [markdown]
# ### `lpm_set`

# %%
ItemFinder("liter").candidate_table

# %% [markdown]
# ### `minute_vent_obs`

# %%
vent_df = ItemFinder("vent").candidate_table
vent_df
# Out:
# item label: Altered Respiratory Status NCP - Interventions; value instances: ['Assess RR pattern, oxygenation, and auscultation', 'HOB > 30 degrees', 'Oral care every 2-4 hours, remove all debris', 'Aspiration precautions', 'Repositioning for optimizing respiratory status', 'Every 2 hour turns', 'Suction PRN', 'Encourage cough and deep breathing', 'Antibiotic therapy for respiratory infection', 'Intubation', 'Culture sputum and blood for new fever', 'Restraints for safety with every 24 hour physician order', 'Nebulizer treatments', 'OOB to chair', 'Daily RSBI', 'PEG or NGT placement for aspiration risk', 'SBT', 'Diuresis', 'Daily wake-up', 'Chest PT', 'Incentive spirometry', 'Ventilator support increased', 'Specialty bed', 'Non-invasive ventilatory support', 'Tracheostomy care and maintenance', 'Extubation', 'Interventions for angioedema', 'Tracheostomy placement', 'Maintain chest tube(s)', 'Other', '---']
# ...

# %% [markdown]
# ### `device_category`
# UCMC mapping reference: https://github.com/kaveriC/CLIF-1.0/blob/main/mCIDE/clif_vocab_respiratory_support_devices.csv

# %%
o2_devices = ItemFinder.item_id_to_value_instances(226732)
o2_devices
# Out:
# item label: O2 Delivery Device(s); value instances: {'Endotracheal tube': 467931, 'Nasal cannula': 417453, 'Tracheostomy tube': 90713, 'Aerosol-cool': 68754, 'Face tent': 60388, 'Trach mask ': 50917, 'High flow nasal cannula': 23248, 'Bipap mask ': 19004, 'High flow neb': 17651, 'Non-rebreather': 10898, 'CPAP mask ': 8529, 'Venti mask ': 5144, 'Other': 4550, 'Medium conc mask ': 4421, 'Oxymizer': 4117, 'T-piece': 3441, 'Ultrasonic neb': 27, 'Vapomist': 15}
# "{'Endotracheal tube': 467931, 'Nasal cannula': 417453, 'Tracheostomy tube': 90713, 'Aerosol-cool': 68754, 'Face tent': 60388, 'Trach mask ': 50917, 'High flow nasal cannula': 23248, 'Bipap mask ': 19004, 'High flow neb': 17651, 'Non-rebreather': 10898, 'CPAP mask ': 8529, 'Venti mask ': 5144, 'Other': 4550, 'Medium conc mask ': 4421, 'Oxymizer': 4117, 'T-piece': 3441, 'Ultrasonic neb': 27, 'Vapomist': 15}"

# %% [markdown]
# ### `mode_category`

# %%
vent_mode = ItemFinder.item_id_to_value_instances(223849)
vent_mode
# Out:
# item label: Ventilator Mode; value instances: ['CPAP/PSV', 'CMV/ASSIST/AutoFlow', 'CMV/ASSIST', 'MMV/PSV/AutoFlow', 'Standby', 'PSV/SBT', 'PRVC/AC', 'PCV+Assist', 'CPAP/PSV+ApnVol', 'SIMV/PSV/AutoFlow', 'MMV/PSV', 'CPAP', 'APRV', 'CMV/AutoFlow', 'CPAP/PPS', 'CPAP/PSV+ApnPres', 'VOL/AC', 'PCV+', 'CMV', 'PCV+/PSV', 'PRES/AC', 'SIMV/PSV', 'APV (cmv)', 'SPONT', 'MMV', 'Apnea Ventilation', 'APRV/Biphasic+ApnVol', 'MMV/AutoFlow', 'APRV/Biphasic+ApnPress', 'SIMV/PRES', 'PRVC/SIMV', 'Ambient', 'SIMV', 'SIMV/AutoFlow', 'SYNCHRON MASTER', 'CPAP/PSV+Apn TCPL', 'SIMV/VOL', 'SYNCHRON SLAVE', 'P-CMV', '(S) CMV']
# ['CPAP/PSV',
#  'CMV/ASSIST/AutoFlow',
#  'CMV/ASSIST',
#  'MMV/PSV/AutoFlow',
#  'Standby',
#  'PSV/SBT',
#  'PRVC/AC',
#  'PCV+Assist',
#  'CPAP/PSV+ApnVol',
#  'SIMV/PSV/AutoFlow',
#  'MMV/PSV',
#  'CPAP',
#  'APRV',
#  'CMV/AutoFlow',
#  'CPAP/PPS',
#  'CPAP/PSV+ApnPres',
#  'VOL/AC',
#  'PCV+',
#  'CMV',
#  'PCV+/PSV',
#  'PRES/AC',
#  'SIMV/PSV',
#  'APV (cmv)',
#  'SPONT',
# ...

# %%
vent_mode_ham = ItemFinder.item_id_to_value_instances(229314)
vent_mode_ham
# Out:
# item label: Ventilator Mode (Hamilton); value instances: ['APV (cmv)', 'SPONT', 'ASV', 'VS', 'P-CMV', 'NIV', 'Ambient', '(S) CMV', 'APRV', 'NIV-ST', 'APV (simv)', 'SIMV', 'P-SIMV', 'DuoPaP', 'nCPAP-PS']
# ['APV (cmv)',
#  'SPONT',
#  'ASV',
#  'VS',
#  'P-CMV',
#  'NIV',
#  'Ambient',
#  '(S) CMV',
#  'APRV',
#  'NIV-ST',
#  'APV (simv)',
#  'SIMV',
#  'P-SIMV',
#  'DuoPaP',
#  'nCPAP-PS']

# %%
ItemFinder.item_id_to_value_instances_categorical(227577).to_frame()
# Out:
#                                    count
# value
# Spontaneous (S)                     9733
# Spontaneous/Timed (S/T) (Back up)    731
# Not applicable                       169
# Timed (T)                             15

# %% [markdown]
# ### MAPPING

# %%
# all the events for item: O2 Delivery Device(s)
item_id_to_events_df(226732)
# Out:
#            subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 38           10000032  29079034  39553978       66056.0  2180-07-23 20:00:00
# 192          10000032  29079034  39553978       88981.0  2180-07-23 14:20:00
# 412          10000032  29079034  39553978       88981.0  2180-07-23 18:00:00
# 515          10000980  26913865  39765666       26402.0  2189-06-27 10:00:00
# 1039         10001217  24597018  37067082        7355.0  2157-11-21 20:00:00
# ...               ...       ...       ...           ...                  ...
# 313644011    19999987  23865745  36195440       74793.0  2145-11-04 09:00:00
# 313644012    19999987  23865745  36195440       74793.0  2145-11-04 09:00:00
# 313644048    19999987  23865745  36195440       74793.0  2145-11-04 10:00:00
# 313644814    19999987  23865745  36195440       91429.0  2145-11-03 11:30:00
# 313644915    19999987  23865745  36195440       91879.0  2145-11-04 20:37:00
#
# ...

# %%
resp_items_df = ItemFinder("Respiratory", col="category").candidate_table
resp_item_ids = resp_items_df["itemid"]
# Out:
# item label: Respiratory Rate; value instances: Max: 2355560.0, Min: 0.0, Mean: 20.459964592066456
# item label: O2 saturation pulseoxymetry; value instances: Max: 9900000.0, Min: -272.0, Mean: 104.82763597187437
# item label: O2 Delivery Device(s); value instances: {'Endotracheal tube': 467931, 'Nasal cannula': 417453, 'Tracheostomy tube': 90713, 'Aerosol-cool': 68754, 'Face tent': 60388, 'Trach mask ': 50917, 'High flow nasal cannula': 23248, 'Bipap mask ': 19004, 'High flow neb': 17651, 'Non-rebreather': 10898, 'CPAP mask ': 8529, 'Venti mask ': 5144, 'Other': 4550, 'Medium conc mask ': 4421, 'Oxymizer': 4117, 'T-piece': 3441, 'Ultrasonic neb': 27, 'Vapomist': 15}
# item label: Inspired O2 Fraction; value instances: Max: 10050.0, Min: 0.0, Mean: 48.94540639505812
# item label: PEEP set; value instances: Max: 8774580.0, Min: -5.0, Mean: 26.214116360816025
# item label: Tidal Volume (observed); value instances: Max: 709461.0, Min: 0.0, Mean: 470.8951592275197
# ...

# %%
resp_events = (
    chartevents.loc[chartevents["stay_id"] == 39765666, :]
    # keep only items that are in the resp category
    .loc[lambda x: x["itemid"].isin(resp_item_ids)]
    # add a column of item label
    .assign(item_label = lambda x: x["itemid"].apply(item_id_to_feature_value))
    .reindex(
        columns = ["stay_id", "charttime", "itemid", "item_label", "value", "valuenum", "valueuom", "warning"]
    )
)

# %%
resp_events.loc[
    resp_events["charttime"] == "2189-06-27 09:00:00",:
]
# Out:
#       stay_id            charttime  itemid                      item_label  \
# 489  39765666  2189-06-27 09:00:00  227287    O2 Flow (additional cannula)
# 490  39765666  2189-06-27 09:00:00  220339                        PEEP set
# 491  39765666  2189-06-27 09:00:00  223848                 Ventilator Type
# 492  39765666  2189-06-27 09:00:00  224685         Tidal Volume (observed)
# 493  39765666  2189-06-27 09:00:00  224686      Tidal Volume (spontaneous)
# 494  39765666  2189-06-27 09:00:00  224687                   Minute Volume
# 495  39765666  2189-06-27 09:00:00  224689  Respiratory Rate (spontaneous)
# 496  39765666  2189-06-27 09:00:00  224690        Respiratory Rate (Total)
# 497  39765666  2189-06-27 09:00:00  224692                    Flow Pattern
# 498  39765666  2189-06-27 09:00:00  224695             Peak Insp. Pressure
# 499  39765666  2189-06-27 09:00:00  224697            Mean Airway Pressure
# ...
